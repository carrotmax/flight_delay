# %%
import numpy as np
import pandas as pd
import datetime as dt
import plotly_express as px
import plotly.graph_objects as go

# %%
data1 = pd.read_csv('flightdata\Jan.csv')
data2 = pd.read_csv('flightdata\Feb.csv')
data3 = pd.read_csv('flightdata\Mar.csv')
data4 = pd.read_csv('flightdata\Apr.csv')
data5 = pd.read_csv('flightdata\May.csv')
data6 = pd.read_csv('flightdata\Jun.csv')
data7 = pd.read_csv('flightdata\Jul.csv')
data8 = pd.read_csv('flightdata\Aug.csv')
data9 = pd.read_csv('flightdata\Sep.csv')
data10 = pd.read_csv('flightdata\Oct.csv')
data11 = pd.read_csv('flightdata\\Nov.csv')
data12 = pd.read_csv('flightdata\Dec.csv')

# %%
def dropyear(df):
    df.drop(['YEAR', 'MONTH', 'DAY_OF_MONTH'], axis=1, inplace=True)
    return df

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70838 entries, 0 to 70837
# Data columns (total 19 columns):
# FL_DATE                70838 non-null object
# TAIL_NUM               70590 non-null object
# OP_CARRIER_FL_NUM      70838 non-null int64
# ORIGIN_AIRPORT_ID      70838 non-null int64
# ORIGIN_STATE_ABR       70838 non-null object
# ORIGIN_STATE_NM        70838 non-null object
# DEST_AIRPORT_ID        70838 non-null int64
# DEST_STATE_ABR         70838 non-null object
# DEST_STATE_NM          70838 non-null object
# DEP_DELAY              70282 non-null float64
# CANCELLED              70838 non-null float64
# FLIGHTS                70838 non-null float64
# DISTANCE               70838 non-null float64
# CARRIER_DELAY          8612 non-null float64
# WEATHER_DELAY          8612 non-null float64
# NAS_DELAY              8612 non-null float64
# SECURITY_DELAY         8612 non-null float64
# LATE_AIRCRAFT_DELAY    8612 non-null float64
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64356 entries, 0 to 64355
# Data columns (total 19 columns):
# FL_DATE                64356 non-null object
# TAIL_NUM               64279 non-null object
# OP_CARRIER_FL_NUM      64356 non-null int64
# ORIGIN_AIRPORT_ID      64356 non-null int64
# ORIGIN_STATE_ABR       64356 non-null object
# ORIGIN_STATE_NM        64356 non-null object
# DEST_AIRPORT_ID        64356 non-null int64
# DEST_STATE_ABR         64356 non-null object
# DEST_STATE_NM          64356 non-null object
# DEP_DELAY              63661 non-null float64
# CANCELLED              64356 non-null float64
# FLIGHTS                64356 non-null float64
# DISTANCE               64356 non-null float64
# CARRIER_DELAY          8324 non-null float64
# WEATHER_DELAY          8324 non-null float64
# NAS_DELAY              8324 non-null float64
# SECURITY_DELAY         8324 non-null float64
# LATE_AIRCRAFT_DELAY    8324 non-null float64
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58369 entries, 0 to 58368
# Data columns (total 19 columns):
# FL_DATE                58369 non-null object
# TAIL_NUM               58326 non-null object
# OP_CARRIER_FL_NUM      58369 non-null int64
# ORIGIN_AIRPORT_ID      58369 non-null int64
# ORIGIN_STATE_ABR       58369 non-null object
# ORIGIN_STATE_NM        58369 non-null object
# DEST_AIRPORT_ID        58369 non-null int64
# DEST_STATE_ABR         58369 non-null object
# DEST_STATE_NM          58369 non-null object
# DEP_DELAY              57932 non-null float64
# CANCELLED              58369 non-null float64
# FLIGHTS                58369 non-null float64
# DISTANCE               58369 non-null float64
# CARRIER_DELAY          10730 non-null float64
# WEATHER_DELAY          10730 non-null float64
# NAS_DELAY              10730 non-null float64
# SECURITY_DELAY         10730 non-null float64
# LATE_AIRCRAFT_DELAY    10730 non-null float64
# ...

# %%
data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68824 entries, 0 to 68823
# Data columns (total 19 columns):
# FL_DATE                68824 non-null object
# TAIL_NUM               68705 non-null object
# OP_CARRIER_FL_NUM      68824 non-null int64
# ORIGIN_AIRPORT_ID      68824 non-null int64
# ORIGIN_STATE_ABR       68824 non-null object
# ORIGIN_STATE_NM        68824 non-null object
# DEST_AIRPORT_ID        68824 non-null int64
# DEST_STATE_ABR         68824 non-null object
# DEST_STATE_NM          68824 non-null object
# DEP_DELAY              68243 non-null float64
# CANCELLED              68824 non-null float64
# FLIGHTS                68824 non-null float64
# DISTANCE               68824 non-null float64
# CARRIER_DELAY          10853 non-null float64
# WEATHER_DELAY          10853 non-null float64
# NAS_DELAY              10853 non-null float64
# SECURITY_DELAY         10853 non-null float64
# LATE_AIRCRAFT_DELAY    10853 non-null float64
# ...

# %%
data5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71771 entries, 0 to 71770
# Data columns (total 19 columns):
# FL_DATE                71771 non-null object
# TAIL_NUM               71722 non-null object
# OP_CARRIER_FL_NUM      71771 non-null int64
# ORIGIN_AIRPORT_ID      71771 non-null int64
# ORIGIN_STATE_ABR       71771 non-null object
# ORIGIN_STATE_NM        71771 non-null object
# DEST_AIRPORT_ID        71771 non-null int64
# DEST_STATE_ABR         71771 non-null object
# DEST_STATE_NM          71771 non-null object
# DEP_DELAY              71325 non-null float64
# CANCELLED              71771 non-null float64
# FLIGHTS                71771 non-null float64
# DISTANCE               71771 non-null float64
# CARRIER_DELAY          10142 non-null float64
# WEATHER_DELAY          10142 non-null float64
# NAS_DELAY              10142 non-null float64
# SECURITY_DELAY         10142 non-null float64
# LATE_AIRCRAFT_DELAY    10142 non-null float64
# ...

# %%
data6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71744 entries, 0 to 71743
# Data columns (total 19 columns):
# FL_DATE                71744 non-null object
# TAIL_NUM               71701 non-null object
# OP_CARRIER_FL_NUM      71744 non-null int64
# ORIGIN_AIRPORT_ID      71744 non-null int64
# ORIGIN_STATE_ABR       71744 non-null object
# ORIGIN_STATE_NM        71744 non-null object
# DEST_AIRPORT_ID        71744 non-null int64
# DEST_STATE_ABR         71744 non-null object
# DEST_STATE_NM          71744 non-null object
# DEP_DELAY              70995 non-null float64
# CANCELLED              71744 non-null float64
# FLIGHTS                71744 non-null float64
# DISTANCE               71744 non-null float64
# CARRIER_DELAY          15822 non-null float64
# WEATHER_DELAY          15822 non-null float64
# NAS_DELAY              15822 non-null float64
# SECURITY_DELAY         15822 non-null float64
# LATE_AIRCRAFT_DELAY    15822 non-null float64
# ...

# %%
data7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73918 entries, 0 to 73917
# Data columns (total 19 columns):
# FL_DATE                73918 non-null object
# TAIL_NUM               73885 non-null object
# OP_CARRIER_FL_NUM      73918 non-null int64
# ORIGIN_AIRPORT_ID      73918 non-null int64
# ORIGIN_STATE_ABR       73918 non-null object
# ORIGIN_STATE_NM        73918 non-null object
# DEST_AIRPORT_ID        73918 non-null int64
# DEST_STATE_ABR         73918 non-null object
# DEST_STATE_NM          73918 non-null object
# DEP_DELAY              73280 non-null float64
# CANCELLED              73918 non-null float64
# FLIGHTS                73918 non-null float64
# DISTANCE               73918 non-null float64
# CARRIER_DELAY          14166 non-null float64
# WEATHER_DELAY          14166 non-null float64
# NAS_DELAY              14166 non-null float64
# SECURITY_DELAY         14166 non-null float64
# LATE_AIRCRAFT_DELAY    14166 non-null float64
# ...

# %%
data8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73904 entries, 0 to 73903
# Data columns (total 19 columns):
# FL_DATE                73904 non-null object
# TAIL_NUM               73874 non-null object
# OP_CARRIER_FL_NUM      73904 non-null int64
# ORIGIN_AIRPORT_ID      73904 non-null int64
# ORIGIN_STATE_ABR       73904 non-null object
# ORIGIN_STATE_NM        73904 non-null object
# DEST_AIRPORT_ID        73904 non-null int64
# DEST_STATE_ABR         73904 non-null object
# DEST_STATE_NM          73904 non-null object
# DEP_DELAY              73494 non-null float64
# CANCELLED              73904 non-null float64
# FLIGHTS                73904 non-null float64
# DISTANCE               73904 non-null float64
# CARRIER_DELAY          12027 non-null float64
# WEATHER_DELAY          12027 non-null float64
# NAS_DELAY              12027 non-null float64
# SECURITY_DELAY         12027 non-null float64
# LATE_AIRCRAFT_DELAY    12027 non-null float64
# ...

# %%
data9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66621 entries, 0 to 66620
# Data columns (total 19 columns):
# FL_DATE                66621 non-null object
# TAIL_NUM               66539 non-null object
# OP_CARRIER_FL_NUM      66621 non-null int64
# ORIGIN_AIRPORT_ID      66621 non-null int64
# ORIGIN_STATE_ABR       66621 non-null object
# ORIGIN_STATE_NM        66621 non-null object
# DEST_AIRPORT_ID        66621 non-null int64
# DEST_STATE_ABR         66621 non-null object
# DEST_STATE_NM          66621 non-null object
# DEP_DELAY              65966 non-null float64
# CANCELLED              66621 non-null float64
# FLIGHTS                66621 non-null float64
# DISTANCE               66621 non-null float64
# CARRIER_DELAY          6251 non-null float64
# WEATHER_DELAY          6251 non-null float64
# NAS_DELAY              6251 non-null float64
# SECURITY_DELAY         6251 non-null float64
# LATE_AIRCRAFT_DELAY    6251 non-null float64
# ...

# %%
data10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70114 entries, 0 to 70113
# Data columns (total 22 columns):
# YEAR                   70114 non-null int64
# MONTH                  70114 non-null int64
# DAY_OF_MONTH           70114 non-null int64
# FL_DATE                70114 non-null object
# TAIL_NUM               70106 non-null object
# OP_CARRIER_FL_NUM      70114 non-null int64
# ORIGIN_AIRPORT_ID      70114 non-null int64
# ORIGIN_STATE_ABR       70114 non-null object
# ORIGIN_STATE_NM        70114 non-null object
# DEST_AIRPORT_ID        70114 non-null int64
# DEST_STATE_ABR         70114 non-null object
# DEST_STATE_NM          70114 non-null object
# DEP_DELAY              69990 non-null float64
# CANCELLED              70114 non-null float64
# FLIGHTS                70114 non-null float64
# DISTANCE               70114 non-null float64
# CARRIER_DELAY          11619 non-null float64
# WEATHER_DELAY          11619 non-null float64
# ...

# %%
data11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64870 entries, 0 to 64869
# Data columns (total 22 columns):
# YEAR                   64870 non-null int64
# MONTH                  64870 non-null int64
# DAY_OF_MONTH           64870 non-null int64
# FL_DATE                64870 non-null object
# TAIL_NUM               64862 non-null object
# OP_CARRIER_FL_NUM      64870 non-null int64
# ORIGIN_AIRPORT_ID      64870 non-null int64
# ORIGIN_STATE_ABR       64870 non-null object
# ORIGIN_STATE_NM        64870 non-null object
# DEST_AIRPORT_ID        64870 non-null int64
# DEST_STATE_ABR         64870 non-null object
# DEST_STATE_NM          64870 non-null object
# DEP_DELAY              64775 non-null float64
# CANCELLED              64870 non-null float64
# FLIGHTS                64870 non-null float64
# DISTANCE               64870 non-null float64
# CARRIER_DELAY          5898 non-null float64
# WEATHER_DELAY          5898 non-null float64
# ...

# %%
data12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67058 entries, 0 to 67057
# Data columns (total 22 columns):
# YEAR                   67058 non-null int64
# MONTH                  67058 non-null int64
# DAY_OF_MONTH           67058 non-null int64
# FL_DATE                67058 non-null object
# TAIL_NUM               67045 non-null object
# OP_CARRIER_FL_NUM      67058 non-null int64
# ORIGIN_AIRPORT_ID      67058 non-null int64
# ORIGIN_STATE_ABR       67058 non-null object
# ORIGIN_STATE_NM        67058 non-null object
# DEST_AIRPORT_ID        67058 non-null int64
# DEST_STATE_ABR         67058 non-null object
# DEST_STATE_NM          67058 non-null object
# DEP_DELAY              66945 non-null float64
# CANCELLED              67058 non-null float64
# FLIGHTS                67058 non-null float64
# DISTANCE               67058 non-null float64
# CARRIER_DELAY          9421 non-null float64
# WEATHER_DELAY          9421 non-null float64
# ...

# %%
dropyear(data10)
dropyear(data11)
dropyear(data12)
# Out:
#           FL_DATE TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0      2019-12-08   N790SW               1349              15304
# 1      2019-12-08   N484WN               2884              15304
# 2      2019-12-08   N7830A               3631              15304
# 3      2019-12-08   N762SW               3874              15304
# 4      2019-12-08   N484WN               6745              15304
# ...           ...      ...                ...                ...
# 67053  2019-12-31   N569JB                568              11697
# 67054  2019-12-31   N589JB                719              12478
# 67055  2019-12-31   N589JB                720              10397
# 67056  2019-12-31   N633JB                841              12478
# 67057  2019-12-31   N633JB                842              14685
#
#       ORIGIN_STATE_ABR ORIGIN_STATE_NM  DEST_AIRPORT_ID DEST_STATE_ABR  \
# 0                   FL         Florida            10397             GA
# ...

# %%
df = pd.concat([data1,data2,data3,data4,data5,data6,data7,data8,data9,data10,data11,data12], axis=0,ignore_index=True)
# Out:
# C:\Users\13863\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
df.fillna(0)
# Out:
#         CANCELLED  CARRIER_DELAY  DEP_DELAY  DEST_AIRPORT_ID DEST_STATE_ABR  \
# 0             0.0            0.0       86.0            10397             GA
# 1             0.0            0.0      -10.0            10599             AL
# 2             0.0            0.0       -7.0            10397             GA
# 3             0.0            0.0       -5.0            10397             GA
# 4             0.0            0.0        0.0            10397             GA
# ...           ...            ...        ...              ...            ...
# 822382        0.0            0.0        0.0            10397             GA
# 822383        0.0            0.0       28.0            10397             GA
# 822384        0.0            0.0        8.0            12478             NY
# 822385        0.0            0.0        0.0            14685             GA
# 822386        0.0            0.0       -1.0            12478             NY
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 822387 entries, 0 to 822386
# Data columns (total 20 columns):
# CANCELLED              822387 non-null float64
# CARRIER_DELAY          123865 non-null float64
# DEP_DELAY              816888 non-null float64
# DEST_AIRPORT_ID        822387 non-null int64
# DEST_STATE_ABR         822387 non-null object
# DEST_STATE_NM          822387 non-null object
# DISTANCE               822387 non-null float64
# FLIGHTS                822387 non-null float64
# FL_DATE                822387 non-null object
# LATE_AIRCRAFT_DELAY    123865 non-null float64
# NAS_DELAY              123865 non-null float64
# OP_CARRIER_FL_NUM      822387 non-null int64
# ORIGIN_AIRPORT_ID      822387 non-null int64
# ORIGIN_STATE_ABR       822387 non-null object
# ORIGIN_STATE_NM        822387 non-null object
# SECURITY_DELAY         123865 non-null float64
# TAIL_NUM               821634 non-null object
# Unnamed: 18            0 non-null float64
# ...

# %%
df.drop(['Unnamed: 18','Unnamed: 21'],axis=1,inplace=True)

# %%
df['count'] = 1
df['FL_DATE'] = pd.to_datetime(df['FL_DATE'],format='%Y-%m-%d')

# %%
df[df['DEST_STATE_ABR']=='GA']
# Out:
#         CANCELLED  CARRIER_DELAY  DEP_DELAY  DEST_AIRPORT_ID DEST_STATE_ABR  \
# 0             0.0            0.0       86.0            10397             GA
# 2             0.0            NaN       -7.0            10397             GA
# 3             0.0            NaN       -5.0            10397             GA
# 4             0.0            NaN        0.0            10397             GA
# 5             0.0            NaN       -3.0            10397             GA
# ...           ...            ...        ...              ...            ...
# 822378        0.0            NaN       -7.0            10397             GA
# 822379        0.0            NaN       -6.0            10397             GA
# 822382        0.0            NaN        0.0            10397             GA
# 822383        0.0            NaN       28.0            10397             GA
# 822385        0.0            NaN        0.0            14685             GA
#
# ...

# %%
bins = [0,300,500,1000]
listlabels = [1,2,3]
df['distance'] = pd.cut(df['DISTANCE'], bins=bins,labels = listlabels)

# %%
df['distance'].value_counts()
# Out:
# 3    393485
# 2    184920
# 1    153606
# Name: distance, dtype: int64

# %%
df['CANCELLED'].value_counts()
# Out:
# 0.0    816747
# 1.0      5640
# Name: CANCELLED, dtype: int64

# %%
df['DEP_DELAY'].min()
# Out:
# -82.0

# %%
df['DEP_DELAY'].max()
# Out:
# 1460.0

# %%
bins = [-100,-1,1,15,60,2000]
listlabels = [1,2,3,4,5]
df['delay'] = pd.cut(df['DEP_DELAY'], bins=bins,labels = listlabels)

# %%
df['delay'].value_counts()
# Out:
# 1    504466
# 3    116781
# 4     83092
# 2     73157
# 5     39392
# Name: delay, dtype: int64

# %%
df.columns
# Out:
# Index(['CANCELLED', 'CARRIER_DELAY', 'DEP_DELAY', 'DEST_AIRPORT_ID',
#        'DEST_STATE_ABR', 'DEST_STATE_NM', 'DISTANCE', 'FLIGHTS', 'FL_DATE',
#        'LATE_AIRCRAFT_DELAY', 'NAS_DELAY', 'OP_CARRIER_FL_NUM',
#        'ORIGIN_AIRPORT_ID', 'ORIGIN_STATE_ABR', 'ORIGIN_STATE_NM',
#        'SECURITY_DELAY', 'TAIL_NUM', 'WEATHER_DELAY', 'count', 'distance',
#        'delay'],
#       dtype='object')

# %%
df[df['ORIGIN_STATE_ABR']=='GA']
# Out:
#         CANCELLED  CARRIER_DELAY  DEP_DELAY  DEST_AIRPORT_ID DEST_STATE_ABR  \
# 1             0.0            NaN      -10.0            10599             AL
# 7             0.0           80.0       94.0            12197             NY
# 10            0.0            NaN       -2.0            15624             FL
# 12            0.0            NaN       -3.0            10208             GA
# 13            0.0            NaN       13.0            15370             OK
# ...           ...            ...        ...              ...            ...
# 822377        0.0            NaN       -1.0            11697             FL
# 822380        0.0            NaN       -9.0            12478             NY
# 822381        0.0            NaN       -2.0            11697             FL
# 822384        0.0            NaN        8.0            12478             NY
# 822386        0.0            NaN       -1.0            12478             NY
#
# ...

# %%
pf = df.drop(['ORIGIN_AIRPORT_ID','DEST_AIRPORT_ID','OP_CARRIER_FL_NUM','ORIGIN_STATE_NM','DEST_STATE_NM'],axis=1)

# %%
pf
# Out:
#         CANCELLED  CARRIER_DELAY  DEP_DELAY DEST_STATE_ABR  DISTANCE  FLIGHTS  \
# 0             0.0            0.0       86.0             GA     164.0      1.0
# 1             0.0            NaN      -10.0             AL     134.0      1.0
# 2             0.0            NaN       -7.0             GA     134.0      1.0
# 3             0.0            NaN       -5.0             GA     448.0      1.0
# 4             0.0            NaN        0.0             GA     306.0      1.0
# ...           ...            ...        ...            ...       ...      ...
# 822382        0.0            NaN        0.0             GA     581.0      1.0
# 822383        0.0            NaN       28.0             GA     760.0      1.0
# 822384        0.0            NaN        8.0             NY     760.0      1.0
# 822385        0.0            NaN        0.0             GA     718.0      1.0
# 822386        0.0            NaN       -1.0             NY     718.0      1.0
#
# ...

# %%
df.columns
# Out:
# Index(['CANCELLED', 'CARRIER_DELAY', 'DEP_DELAY', 'DEST_AIRPORT_ID',
#        'DEST_STATE_ABR', 'DEST_STATE_NM', 'DISTANCE', 'FLIGHTS', 'FL_DATE',
#        'LATE_AIRCRAFT_DELAY', 'NAS_DELAY', 'OP_CARRIER_FL_NUM',
#        'ORIGIN_AIRPORT_ID', 'ORIGIN_STATE_ABR', 'ORIGIN_STATE_NM',
#        'SECURITY_DELAY', 'TAIL_NUM', 'WEATHER_DELAY', 'count', 'distance',
#        'delay'],
#       dtype='object')

# %%
tf = df.groupby(['ORIGIN_STATE_ABR','FL_DATE'],as_index= False)['count','DEP_DELAY'].sum()

# %%
kf = df.groupby(['ORIGIN_STATE_ABR','FL_DATE'],as_index= False)['count','DEP_DELAY'].sum()

# %%
ZF= kf.loc[kf.ORIGIN_STATE_ABR=='AK']

# %%
kf.drop(kf[kf.ORIGIN_STATE_ABR=='AK'].index,inplace=True)

# %%
kf.reset_index(inplace = True)

# %%
kf
# Out:
#        index ORIGIN_STATE_ABR    FL_DATE  count  DEP_DELAY
# 0        112               AL 2019-01-01     18      167.0
# 1        113               AL 2019-01-02     30      104.0
# 2        114               AL 2019-01-03     28      -13.0
# 3        115               AL 2019-01-04     27      198.0
# 4        116               AL 2019-01-05     22     -114.0
# ...      ...              ...        ...    ...        ...
# 16830  16942               WY 2019-12-27      1      188.0
# 16831  16943               WY 2019-12-28      1       69.0
# 16832  16944               WY 2019-12-29      1       43.0
# 16833  16945               WY 2019-12-30      1       59.0
# 16834  16946               WY 2019-12-31      1      179.0
#
# [16835 rows x 5 columns]

# %%
SF['FL_DATE']= kf.loc[kf.ORIGIN_STATE_ABR=='KY']['FL_DATE']
# Out:
# C:\Users\13863\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
kk = {'ORIGIN_STATE_ABR':[],'FL_DATE':[],'count':[],'DEP_DELAY':[]}

SF = pd.DataFrame(kk)

# %%
SF['FL_DATE'] = kf.loc[kf.ORIGIN_STATE_ABR=='KY']['FL_DATE']
SF['ORIGIN_STATE_ABR'] = 'AK'
result = pd.merge(SF, ZF, how='outer',on=['ORIGIN_STATE_ABR', 'FL_DATE'])

# %%
result.fillna(0,inplace= True)

# %%
result.drop(['count_x','DEP_DELAY_x'],axis=1,inplace = True)

# %%
tf['ORIGIN_STATE_ABR'].value_counts()
# Out:
# KY    365
# AR    365
# MD    365
# OH    365
# NJ    365
# CO    365
# MI    365
# NV    365
# WA    365
# MA    365
# VA    365
# CA    365
# RI    365
# CT    365
# OR    365
# FL    365
# GA    365
# MN    365
# NM    365
# TX    365
# TN    365
# KS    365
# AZ    365
# MO    365
# IA    365
# PA    365
# LA    365
# NE    365
# OK    365
# IL    365
# MS    365
# UT    365
# WV    365
# SC    365
# PR    365
# NC    365
# IN    365
# AL    365
# WI    365
# NY    365
# VT    364
# HI    354
# VI    353
# ME    351
# SD    327
# NH    270
# AK    112
# WY    104
# MT     88
# ND     24
# Name: ORIGIN_STATE_ABR, dtype: int64

# %%
result.loc[result.FL_DATE=='2019-06-06']
# Out:
#     ORIGIN_STATE_ABR    FL_DATE  count_y  DEP_DELAY_y
# 156               AK 2019-06-06      1.0         -3.0

# %%
result
# Out:
#     ORIGIN_STATE_ABR    FL_DATE  count_y  DEP_DELAY_y
# 0                 AK 2019-01-01      0.0          0.0
# 1                 AK 2019-01-02      0.0          0.0
# 2                 AK 2019-01-03      0.0          0.0
# 3                 AK 2019-01-04      0.0          0.0
# 4                 AK 2019-01-05      0.0          0.0
# ..               ...        ...      ...          ...
# 360               AK 2019-12-27      0.0          0.0
# 361               AK 2019-12-28      0.0          0.0
# 362               AK 2019-12-29      0.0          0.0
# 363               AK 2019-12-30      0.0          0.0
# 364               AK 2019-12-31      0.0          0.0
#
# [365 rows x 4 columns]

# %%
tf['FL_DATE'] = tf['FL_DATE'].astype(str)

# %%
tf = tf[~tf['ORIGIN_STATE_ABR'].isin(['AK','VT','HI','VI','ME','SD','NH','WY','MT','ND','GA'])]

# %%
Vermont                  1
Hawaii                  11
U.S. Virgin Islands     12
Maine                   14
South Dakota            38
New Hampshire           95
Alaska                 253
Wyoming                261
Montana                277
North Dakota           341
# Out:
#       ORIGIN_STATE_ABR     FL_DATE  count  DEP_DELAY
# 112                 AL  2019-01-01     18      167.0
# 113                 AL  2019-01-02     30      104.0
# 114                 AL  2019-01-03     28      -13.0
# 115                 AL  2019-01-04     27      198.0
# 116                 AL  2019-01-05     22     -114.0
# ...                ...         ...    ...        ...
# 16838               WV  2019-12-27      4       30.0
# 16839               WV  2019-12-28      4       -7.0
# 16840               WV  2019-12-29      4       24.0
# 16841               WV  2019-12-30      4      500.0
# 16842               WV  2019-12-31      2        0.0
#
# [14235 rows x 4 columns]

# %%
tf['ORIGIN_STATE_ABR'].value_counts()
# Out:
# KY    365
# RI    365
# CO    365
# MI    365
# NV    365
# WA    365
# MA    365
# VA    365
# CA    365
# CT    365
# OH    365
# OR    365
# FL    365
# MN    365
# NM    365
# TX    365
# TN    365
# KS    365
# NJ    365
# MD    365
# MO    365
# LA    365
# NE    365
# OK    365
# IL    365
# MS    365
# UT    365
# PR    365
# SC    365
# NC    365
# IA    365
# IN    365
# AL    365
# WI    365
# NY    365
# WV    365
# PA    365
# AR    365
# AZ    365
# Name: ORIGIN_STATE_ABR, dtype: int64

# %%
tf['lgcount'] = np.log(tf['count']+1)

# %%
px.choropleth(tf,
              locationmode="USA-states",
              scope="usa",
              locations="ORIGIN_STATE_ABR",
              color="lgcount",
              hover_name="ORIGIN_STATE_ABR",
              hover_data=["count"],
               animation_frame="FL_DATE",
              color_continuous_scale=px.colors.sequential.OrRd,
              range_color=(0, 7),
              title = 'flight')
# Out:
# <div>
#
#
#             <div id="06a517a6-2b37-44e0-941f-c3e803cd0bee" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("06a517a6-2b37-44e0-941f-c3e803cd0bee")) {
#                     Plotly.newPlot(
#                         '06a517a6-2b37-44e0-941f-c3e803cd0bee',
# ...

# %%
weather = pd.read_csv('weather2.csv', low_memory=False)

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12460 entries, 0 to 12459
# Data columns (total 11 columns):
# DATE                        12460 non-null object
# HourlyPrecipitation         9503 non-null object
# HourlyPresentWeatherType    1964 non-null object
# HourlyPressureChange        4352 non-null float64
# HourlyRelativeHumidity      12082 non-null float64
# HourlySeaLevelPressure      10240 non-null float64
# HourlySkyConditions         11419 non-null object
# HourlyStationPressure       12021 non-null float64
# HourlyVisibility            12082 non-null object
# HourlyWindDirection         12043 non-null object
# HourlyWindSpeed             12080 non-null float64
# dtypes: float64(5), object(6)
# memory usage: 1.0+ MB

# %%
weather = pd.read_csv('weather.csv')

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12460 entries, 0 to 12459
# Data columns (total 13 columns):
# DATE                        12460 non-null object
# HourlyPrecipitation         9503 non-null object
# HourlyPresentWeatherType    1964 non-null object
# HourlyPressureChange        4352 non-null float64
# HourlyRelativeHumidity      12082 non-null float64
# HourlySeaLevelPressure      10240 non-null float64
# HourlySkyConditions         11419 non-null object
# HourlyStationPressure       12021 non-null float64
# HourlyVisibility            12082 non-null float64
# HourlyWindDirection         12043 non-null object
# HourlyWindSpeed             12080 non-null float64
# HourlyDryBulbTemperature    12082 non-null object
# HourlyStationPressure.1     12021 non-null float64
# dtypes: float64(7), object(6)
# memory usage: 1.2+ MB

# %%
weather.loc[weather.HourlyDryBulbTemperature=='96s']
# Out:
#                      DATE HourlyPrecipitation HourlyPresentWeatherType  \
# 9370  2019-10-04T13:00:00                 NaN                      NaN
#
#       HourlyPressureChange  HourlyRelativeHumidity  HourlySeaLevelPressure  \
# 9370                  0.04                    30.0                   29.99
#
#      HourlySkyConditions  HourlyStationPressure  HourlyVisibility  \
# 9370                  74                  28.92              9.94
#
#      HourlyWindDirection  HourlyWindSpeed HourlyDryBulbTemperature  \
# 9370                 330              7.0                      96s
#
#       HourlyStationPressure.1
# 9370                    28.92
